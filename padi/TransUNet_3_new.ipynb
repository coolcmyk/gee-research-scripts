# %%
# !pip install rasterio
# Out:
# Requirement already satisfied: rasterio in /usr/local/lib/python3.12/dist-packages (1.5.0)
# Requirement already satisfied: affine in /usr/local/lib/python3.12/dist-packages (from rasterio) (2.4.0)
# Requirement already satisfied: attrs in /usr/local/lib/python3.12/dist-packages (from rasterio) (26.1.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from rasterio) (2026.5.20)
# Requirement already satisfied: click!=8.2.*,>=4.0 in /usr/local/lib/python3.12/dist-packages (from rasterio) (8.4.0)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.12/dist-packages (from rasterio) (0.7.2)
# Requirement already satisfied: numpy>=2 in /usr/local/lib/python3.12/dist-packages (from rasterio) (2.0.2)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.12/dist-packages (from rasterio) (3.3.2)

# %%
import rasterio as rio
from rasterio.plot import show
import os
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.layers import *
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix, cohen_kappa_score, accuracy_score, f1_score, precision_score, recall_score
import seaborn as sns
import pandas as pd
import time

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
class SlidingWindowSplitter:
    """Splitter for image/mask that takes evenly-spaced square patches.

    Attributes
    ----------
    patch_size : int
        Sidelength of extracted patches.
    stride : int
        Spacing between adjacent extractions.
    filters : list, optional
        All filters for patches that disallow certain criteria (default is
        None).
    """
    def __init__(self, patch_size, stride, filters=None):
        self.patch_size = patch_size
        self.stride = stride
        self.filters = filters

    def __call__(self, bands, mask):
        """Extracts evenly-spaced square patches from data.

        Parameters
        ----------
        bands : np.ndarray
            Band data for scene, aggregated into single 3D-array.
        mask : np.ndarray, bool
            One-hot encoded mask for scene.

        Returns
        -------
        bands_patches : list
            All extracted band data patches.
        mask_patches : list
            All extracted mask patches.
        patch_ids : list
            Identifiers for each patch based on x/y location.
        """
        if self.patch_size is not None:
            n_x = (bands.shape[0] - self.patch_size) // self.stride + 1
            n_y = (bands.shape[1] - self.patch_size) // self.stride + 1
            step_x = self.stride
            step_y = self.stride

            # pre-allocated for efficiency
            bands_patches = np.empty((n_x * n_y, self.patch_size, self.patch_size, bands.shape[-1]))
            mask_patches = np.empty((n_x * n_y, self.patch_size, self.patch_size,mask.shape[-1]))
            patch_ids = []
            num_valid_patches = 0
            for i in range(n_x):
                for j in range(n_y):
                    region = slice(i * step_x, i * step_x + self.patch_size), \
                             slice(j * step_y, j * step_y + self.patch_size), ...
                    bands_patch = bands[region]
                    mask_patch = mask[region]

                    if self.filters is not None:
                        if not all([filter(bands_patch, mask_patch) for filter in self.filters]):
                            continue

                    bands_patches[num_valid_patches, ...] = bands_patch
                    mask_patches[num_valid_patches, ...] = mask_patch
                    patch_ids.append(str(i).zfill(3) + str(j).zfill(3))
                    num_valid_patches += 1

            bands_patches = [bands_patches[i, ...] for i in range(num_valid_patches)]
            mask_patches = [mask_patches[i, ...] for i in range(num_valid_patches)]
        else:
            bands_patches = [bands]
            mask_patches = [mask]
            patch_ids = ['data']

        return bands_patches, mask_patches, patch_ids

# %%
def load_data(data_dir, mask_dir, file_name, mask_name, window):
    sentinel_data = []
    mask_data = []
    data_files = [f for f in os.listdir(data_dir) if f.startswith(file_name)]

    for filename in data_files:

        dirname = data_dir + filename
        with rio.open(dirname) as src:
            s_data = src.read()
            s_data = np.moveaxis(s_data, 0, -1)

        maskname = mask_dir + mask_name
        with rio.open(maskname) as src:
            mask = src.read()
            mask = np.moveaxis(mask, 0, -1)

        # Split sentinel data and mask
        splitter = SlidingWindowSplitter(window, window)
        sentinel_split, mask_split, patch_ids = splitter(s_data, mask)

        # Append splitted data into the array
        sentinel_data.append(sentinel_split)
        mask_data.append(mask_split)

    sentinel_data = np.array(sentinel_data)
    mask_data = np.array(mask_data)

    return sentinel_data, mask_data

data_dir = '/content/drive/MyDrive/S2_NDWI_Filtered/'
mask_dir = '/content/drive/MyDrive/Skripsi_Padi/Groundtruth/'
window = 128
# sentinel_data1, mask_data1 = load_data(data_dir, mask_dir, '1', 'Mask_1.tif', window)
# sentinel_data2, mask_data2 = load_data(data_dir, mask_dir, '2', 'Mask_2.tif', window)
# sentinel_data3, mask_data3 = load_data(data_dir, mask_dir, '3', 'Mask_3.tif', window)
# sentinel_data4, mask_data4 = load_data(data_dir, mask_dir, '4', 'Mask_4.tif', window)

sentinel_data1, mask_data1 = load_data(data_dir, mask_dir, '1_', 'Mask_1_training.tif', window)
sentinel_data2, mask_data2 = load_data(data_dir, mask_dir, '2_', 'Mask_2_training.tif', window)
sentinel_data3, mask_data3 = load_data(data_dir, mask_dir, '3_', 'Mask_3_training.tif', window)
sentinel_data4, mask_data4 = load_data(data_dir, mask_dir, '4_', 'Mask_4_training.tif', window)

sentinel_data = np.concatenate((sentinel_data1, sentinel_data2, sentinel_data3, sentinel_data4))
mask_data = np.concatenate((mask_data1, mask_data2, mask_data3, mask_data4))

# Reshape from divided from 4 (... x 4, 256, 256, 10) into ...
sentinel_data = np.reshape(sentinel_data, (sentinel_data.shape[0] * sentinel_data.shape[1], sentinel_data.shape[2], sentinel_data.shape[3], sentinel_data.shape[4]))
mask_data = np.reshape(mask_data, (mask_data.shape[0] * mask_data.shape[1], mask_data.shape[2], mask_data.shape[3], mask_data.shape[4]))

print(f"Loaded {len(sentinel_data)} sentinel data and {len(mask_data)} masks data.")
# Out:
# Loaded 1088 sentinel data and 1088 masks data.

# %%
import random

augmented_sentinel_data = []
augmented_mask_data = []

def random_flip_and_rotate(image, mask):
    # Randomly flip
    if random.random() > 0.5:
        image = np.flipud(image)  # Vertical flip
        mask = np.flipud(mask)

    if random.random() > 0.5:
        image = np.fliplr(image)  # Horizontal flip
        mask = np.fliplr(mask)

    # Randomly rotate by 90, 180, or 270 degrees
    rotations = random.choice([0, 1, 2, 3])  # 0: no rotation, 1: 90, 2: 180, 3: 270
    if rotations > 0:
        image = np.rot90(image, rotations, axes=(0, 1))  # Rotate along the spatial axes
        mask = np.rot90(mask, rotations)

    return image, mask

# Loop through original data to augment
for i in range(sentinel_data.shape[0]):
    img = sentinel_data[i]
    msk = mask_data[i]

    # Append the original data
    augmented_sentinel_data.append(img)
    augmented_mask_data.append(msk)

    # Augment the data
    aug_img, aug_msk = random_flip_and_rotate(img, msk)

    # Append the augmented data
    augmented_sentinel_data.append(aug_img)
    augmented_mask_data.append(aug_msk)

# Convert the augmented data back to numpy arrays
sentinel_data = np.array(augmented_sentinel_data)
mask_data = np.array(augmented_mask_data)

# Check the shape of the augmented dataset
print(f"Augmented data shape: {sentinel_data.shape}, augmented mask shape: {mask_data.shape}")
# Out:
# Augmented data shape: (2176, 128, 128, 1), augmented mask shape: (2176, 128, 128, 1)

# %%
# Display example data loaded
plt.figure(figsize = (20, 18))
for i in range(4):
    plt.subplot(4,4,1 + i)
    plt.imshow(sentinel_data[i,:,:,-1].squeeze())
    plt.subplot(4,4,1 + i+4)
    plt.imshow(mask_data[i,:,:,0].squeeze(), cmap='gray')

# %%
# Split data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(sentinel_data, mask_data, test_size=0.2, random_state=42)
print(f"Training set size: {len(X_train)}")
print(f"Test set size: {len(X_test)}")
# Out:
# Training set size: 1740
# Test set size: 436

# %%
del sentinel_data1, sentinel_data2, sentinel_data3, sentinel_data4
del mask_data1, mask_data2, mask_data3, mask_data4
del sentinel_data
del mask_data

# %%
def transformer_block(x, num_heads, ff_dim, mlp_dim=3072, rate=0.1):
    skip_1 = x
    x = layers.LayerNormalization()(x)

    # Multi-Head Self Attention
    attn_output = layers.MultiHeadAttention(num_heads=num_heads, key_dim=ff_dim)(x, x)

    # Residual connection
    out1 = layers.Add()([attn_output, skip_1])
    skip_2 = out1

    # Layer Normalization
    out1_norm = layers.LayerNormalization()(out1)

    # MLP
    ffn_output = layers.Dense(mlp_dim, activation='gelu')(out1_norm)
    ffn_output = layers.Dropout(rate)(ffn_output)
    ffn_output = layers.Dense(x.shape[-1])(ffn_output)
    ffn_output = layers.Dropout(rate)(ffn_output)

    # Residual connection
    out2 = layers.Add()([ffn_output, skip_2])

    # Skip connection
    return out2

def conv_block(input_tensor, num_filters):
    x = layers.Conv2D(num_filters, (3, 3), padding='same')(input_tensor)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(num_filters, (3, 3), padding='same')(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    return x

def encoder_block(input_tensor, num_filters):
    x = conv_block(input_tensor, num_filters)
    p = layers.MaxPooling2D((2, 2))(x)
    return x, p

def decoder_block(input_tensor, skip_features, num_filters):
    x = layers.Conv2DTranspose(num_filters, (2,2), strides=2, padding='same')(input_tensor)
    x = layers.concatenate([x, skip_features])
    x = conv_block(x, num_filters)
    return x

def transunet(input_shape, num_filters, num_heads=4, ff_dim=768, dropout_rate=0.1, num_layers=12):
    inputs = layers.Input(input_shape)

    # Encoder
    s1, p1 = encoder_block(inputs, num_filters[0])
    s2, p2 = encoder_block(p1, num_filters[1])
    s3, p3 = encoder_block(p2, num_filters[2])
    s4, p4 = encoder_block(p3, num_filters[3])

    # Bottleneck + Transformer Block
    for i in range(num_layers):
      b = transformer_block(p4, num_heads=num_heads, ff_dim=ff_dim, rate=dropout_rate)

    # Decoder
    d1 = decoder_block(b, s4, num_filters[3])
    d2 = decoder_block(d1, s3, num_filters[2])
    d3 = decoder_block(d2, s2, num_filters[1])
    d4 = decoder_block(d3, s1, num_filters[0])

    # Output
    outputs = layers.Conv2D(1, (1, 1), activation='sigmoid')(d4)

    model = Model(inputs, outputs, name="TransUNet")
    return model

# %%
input_shape = (X_train.shape[1], X_train.shape[2], X_train.shape[3])
num_filters = [32, 64, 128, 256]

optimizer = Adam(learning_rate=1e-4)
model = transunet(input_shape, num_filters)

lr_scheduler = ReduceLROnPlateau(monitor='loss', factor=0.5, patience=5, min_lr=1e-5)
early_stopping = EarlyStopping(monitor='val_loss', patience=15, restore_best_weights=True)

model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])

# %%
# !pip install rasterio psutil GPUtil -q

import psutil
import GPUtil
import threading
import time as _time
from IPython.display import display
import pandas as pd
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping, Callback


def get_resource_snapshot():
    cpu = psutil.cpu_percent(interval=0.5)
    ram = psutil.virtual_memory()
    snapshot = {
        'cpu_pct': cpu,
        'ram_used_gb': ram.used / 1e9,
        'ram_total_gb': ram.total / 1e9,
        'ram_pct': ram.percent,
    }
    gpus = GPUtil.getGPUs()
    if gpus:
        g = gpus[0]
        snapshot.update({
            'gpu_util_pct': g.load * 100,
            'gpu_mem_used_mb': g.memoryUsed,
            'gpu_mem_total_mb': g.memoryTotal,
            'gpu_mem_pct': g.memoryUtil * 100,
        })
    else:
        snapshot.update({'gpu_util_pct': None, 'gpu_mem_used_mb': None,
                         'gpu_mem_total_mb': None, 'gpu_mem_pct': None})
    return snapshot

def print_snapshot(label=""):
    s = get_resource_snapshot()
    print(f"\n{'='*50}")
    print(f"  Resource Snapshot: {label}")
    print(f"{'='*50}")
    print(f"  CPU Usage       : {s['cpu_pct']:.1f}%")
    print(f"  RAM Used        : {s['ram_used_gb']:.2f} GB / {s['ram_total_gb']:.2f} GB  ({s['ram_pct']:.1f}%)")
    if s['gpu_mem_used_mb']:
        print(f"  GPU Utilization : {s['gpu_util_pct']:.1f}%")
        print(f"  GPU Memory      : {s['gpu_mem_used_mb']:.0f} MB / {s['gpu_mem_total_mb']:.0f} MB  ({s['gpu_mem_pct']:.1f}%)")
    else:
        print("  GPU             : Not detected")
    print(f"{'='*50}\n")


class ResourceMonitorCallback(Callback):
    """Logs CPU, RAM, and GPU stats at the end of every epoch."""

    def __init__(self, log_every_n_epochs=1):
        super().__init__()
        self.log_every_n_epochs = log_every_n_epochs
        self.epoch_logs = []          # stores per-epoch records
        self._epoch_start_time = None

    def on_train_begin(self, logs=None):
        self.train_start = _time.time()
        print_snapshot("Training Begin")

    def on_epoch_begin(self, epoch, logs=None):
        self._epoch_start_time = _time.time()

    def on_epoch_end(self, epoch, logs=None):
        epoch_dur = _time.time() - self._epoch_start_time
        s = get_resource_snapshot()
        record = {
            'epoch': epoch + 1,
            'epoch_time_s': round(epoch_dur, 1),
            'cpu_pct': s['cpu_pct'],
            'ram_used_gb': round(s['ram_used_gb'], 2),
            'ram_pct': round(s['ram_pct'], 1),
            'gpu_util_pct': s['gpu_util_pct'],
            'gpu_mem_used_mb': s['gpu_mem_used_mb'],
            'gpu_mem_pct': round(s['gpu_mem_pct'], 1) if s['gpu_mem_pct'] else None,
            'train_loss': round(logs.get('loss', 0), 4),
            'val_loss': round(logs.get('val_loss', 0), 4),
        }
        self.epoch_logs.append(record)

        if (epoch + 1) % self.log_every_n_epochs == 0:
            print(
                f"  [Epoch {epoch+1:03d}]  "
                f"time={epoch_dur:.1f}s | "
                f"CPU={s['cpu_pct']:.0f}% | "
                f"RAM={s['ram_used_gb']:.2f}GB ({s['ram_pct']:.0f}%) | "
                + (f"GPU={s['gpu_util_pct']:.0f}% | GPU_Mem={s['gpu_mem_used_mb']:.0f}MB"
                   if s['gpu_mem_used_mb'] else "GPU=N/A")
            )

    def on_train_end(self, logs=None):
        total_train_time = _time.time() - self.train_start
        print(f"\n{'='*60}")
        print(f"  Training Complete — Total wall time: {total_train_time:.1f}s")
        print(f"{'='*60}")
        print_snapshot("After Training")

    def get_log_df(self):
        return pd.DataFrame(self.epoch_logs)

    def get_usage(self) -> None:
        df = self.get_log_df()
        if df.empty:
            print("No logs recorded. Run training first.")
            return

        has_gpu = df['gpu_mem_used_mb'].notna().any()

        metrics = [
            ("Epoch Time (s)",   "epoch_time_s",   ".1f"),
            ("CPU (%)",          "cpu_pct",        ".1f"),
            ("RAM (GB)",         "ram_used_gb",    ".2f"),
            ("RAM (%)",          "ram_pct",        ".1f"),
            ("Train Loss",       "train_loss",     ".4f"),
            ("Val Loss",         "val_loss",       ".4f"),
        ]
        if has_gpu:
            metrics += [
                ("GPU Util (%)",    "gpu_util_pct",    ".1f"),
                ("GPU Memory (MB)", "gpu_mem_used_mb", ".1f"),
            ]

        col_w = 20
        print(f"\n{'═'*62}")
        print(f"  POST-TRAINING RESOURCE USAGE  ({len(df)} epochs)")
        print(f"{'═'*62}")
        print(f"  {'Metric':<{col_w}}  {'Avg':>8}  {'Max':>8}  {'Min':>8}")
        print(f"  {'-'*col_w}  {'-'*8}  {'-'*8}  {'-'*8}")

        for label, col, fmt in metrics:
            series = df[col].dropna()
            if series.empty:
                continue
            avg  = format(series.mean(), fmt)
            peak = format(series.max(),  fmt)
            low  = format(series.min(),  fmt)
            print(f"  {label:<{col_w}}  {avg:>8}  {peak:>8}  {low:>8}")

        print(f"{'═'*62}\n")


resource_monitor = ResourceMonitorCallback(log_every_n_epochs=1)
# Out:
#   Preparing metadata (setup.py) ... done
#   Building wheel for GPUtil (setup.py) ... done

# %%
train_start_time = time.time()

#history = model.fit(X_train, y_train, epochs=100, batch_size=8, validation_split=0.2, verbose=2)
history = model.fit(X_train, y_train, epochs=150, batch_size=8, validation_split=0.25, callbacks=[lr_scheduler, early_stopping, resource_monitor], verbose=2)
# history = model.fit(X_train, y_train, epochs=150, batch_size=8, validation_split=0.25, callbacks=[lr_scheduler], verbose=2)

train_end_time = time.time()
# Out:
# ==================================================
#   Resource Snapshot: Training Begin
# ==================================================
#   CPU Usage       : 0.7%
#   RAM Used        : 3.63 GB / 179.37 GB  (2.9%)
#   GPU Utilization : 0.0%
#   GPU Memory      : 940 MB / 81920 MB  (1.1%)
# ==================================================
#
# Epoch 1/150
#   [Epoch 001]  time=65.8s | CPU=1% | RAM=4.75GB (4%) | GPU=0% | GPU_Mem=4554MB
# 164/164 - 66s - 404ms/step - accuracy: 0.7471 - loss: 0.5228 - val_accuracy: 0.4306 - val_loss: 3.8499 - learning_rate: 1.0000e-04
# Epoch 2/150
#   [Epoch 002]  time=2.3s | CPU=1% | RAM=4.76GB (4%) | GPU=0% | GPU_Mem=4556MB
# 164/164 - 3s - 17ms/step - accuracy: 0.8226 - loss: 0.4141 - val_accuracy: 0.4306 - val_loss: 7.4795 - learning_rate: 1.0000e-04
# Epoch 3/150
#   [Epoch 003]  time=2.3s | CPU=3% | RAM=4.78GB (4%) | GPU=0% | GPU_Mem=4556MB
# 164/164 - 3s - 17ms/step - accuracy: 0.8420 - loss: 0.3733 - val_accuracy: 0.4377 - val_loss: 2.8460 - learning_rate: 1.0000e-04
# Epoch 4/150
#   [Epoch 004]  time=2.3s | CPU=1% | RAM=4.78GB (4%) | GPU=0% | GPU_Mem=4556MB
# 164/164 - 3s - 17ms/step - accuracy: 0.8601 - loss: 0.3396 - val_accuracy: 0.5987 - val_loss: 1.1301 - learning_rate: 1.0000e-04
# Epoch 5/150
#   [Epoch 005]  time=2.3s | CPU=1% | RAM=4.80GB (4%) | GPU=0% | GPU_Mem=4556MB
# 164/164 - 3s - 17ms/step - accuracy: 0.8604 - loss: 0.3387 - val_accuracy: 0.8614 - val_loss: 0.3354 - learning_rate: 1.0000e-04
# Epoch 6/150
#   [Epoch 006]  time=2.3s | CPU=0% | RAM=4.78GB (4%) | GPU=0% | GPU_Mem=4556MB
# 164/164 - 3s - 17ms/step - accuracy: 0.8821 - loss: 0.2967 - val_accuracy: 0.9060 - val_loss: 0.2483 - learning_rate: 1.0000e-04
# Epoch 7/150
#   [Epoch 007]  time=2.3s | CPU=0% | RAM=4.79GB (4%) | GPU=0% | GPU_Mem=4556MB
# 164/164 - 3s - 17ms/step - accuracy: 0.8858 - loss: 0.2877 - val_accuracy: 0.8739 - val_loss: 0.3107 - learning_rate: 1.0000e-04
# Epoch 8/150
#   [Epoch 008]  time=2.3s | CPU=9% | RAM=4.83GB (4%) | GPU=0% | GPU_Mem=4556MB
# 164/164 - 3s - 17ms/step - accuracy: 0.8892 - loss: 0.2823 - val_accuracy: 0.8935 - val_loss: 0.2794 - learning_rate: 1.0000e-04
# Epoch 9/150
#   [Epoch 009]  time=2.3s | CPU=2% | RAM=4.81GB (4%) | GPU=0% | GPU_Mem=4556MB
# 164/164 - 3s - 17ms/step - accuracy: 0.9030 - loss: 0.2555 - val_accuracy: 0.9102 - val_loss: 0.2431 - learning_rate: 1.0000e-04
# Epoch 10/150
#   [Epoch 010]  time=2.3s | CPU=1% | RAM=4.81GB (4%) | GPU=0% | GPU_Mem=4556MB
# 164/164 - 3s - 17ms/step - accuracy: 0.9140 - loss: 0.2313 - val_accuracy: 0.9005 - val_loss: 0.2351 - learning_rate: 1.0000e-04
# Epoch 11/150
#   [Epoch 011]  time=2.2s | CPU=0% | RAM=4.82GB (4%) | GPU=0% | GPU_Mem=4556MB
# 164/164 - 3s - 17ms/step - accuracy: 0.9108 - loss: 0.2357 - val_accuracy: 0.8989 - val_loss: 0.2591 - learning_rate: 1.0000e-04
# Epoch 12/150
#   [Epoch 012]  time=2.3s | CPU=8% | RAM=4.82GB (4%) | GPU=0% | GPU_Mem=4556MB
# 164/164 - 3s - 17ms/step - accuracy: 0.9175 - loss: 0.2191 - val_accuracy: 0.9252 - val_loss: 0.1965 - learning_rate: 1.0000e-04
# Epoch 13/150
#   [Epoch 013]  time=2.3s | CPU=0% | RAM=4.80GB (4%) | GPU=0% | GPU_Mem=4556MB
# 164/164 - 3s - 17ms/step - accuracy: 0.9197 - loss: 0.2138 - val_accuracy: 0.9255 - val_loss: 0.2010 - learning_rate: 1.0000e-04
# Epoch 14/150
#   [Epoch 014]  time=2.3s | CPU=0% | RAM=4.81GB (4%) | GPU=0% | GPU_Mem=4556MB
# 164/164 - 3s - 17ms/step - accuracy: 0.9295 - loss: 0.1930 - val_accuracy: 0.9281 - val_loss: 0.1949 - learning_rate: 1.0000e-04
# Epoch 15/150
#   [Epoch 015]  time=2.3s | CPU=0% | RAM=4.83GB (4%) | GPU=0% | GPU_Mem=4556MB
# 164/164 - 3s - 17ms/step - accuracy: 0.9368 - loss: 0.1782 - val_accuracy: 0.9318 - val_loss: 0.1815 - learning_rate: 1.0000e-04
# Epoch 16/150
#   [Epoch 016]  time=2.3s | CPU=0% | RAM=4.82GB (4%) | GPU=0% | GPU_Mem=4556MB
# 164/164 - 3s - 17ms/step - accuracy: 0.9274 - loss: 0.1976 - val_accuracy: 0.8855 - val_loss: 0.2932 - learning_rate: 1.0000e-04
# Epoch 17/150
#   [Epoch 017]  time=2.3s | CPU=10% | RAM=4.83GB (4%) | GPU=0% | GPU_Mem=4556MB
# 164/164 - 3s - 17ms/step - accuracy: 0.9290 - loss: 0.1924 - val_accuracy: 0.9268 - val_loss: 0.1984 - learning_rate: 1.0000e-04
# Epoch 18/150
#   [Epoch 018]  time=2.3s | CPU=1% | RAM=4.83GB (4%) | GPU=0% | GPU_Mem=4556MB
# 164/164 - 3s - 17ms/step - accuracy: 0.9380 - loss: 0.1728 - val_accuracy: 0.9293 - val_loss: 0.1803 - learning_rate: 1.0000e-04
# Epoch 19/150
#   [Epoch 019]  time=2.3s | CPU=0% | RAM=4.83GB (4%) | GPU=0% | GPU_Mem=4556MB
# 164/164 - 3s - 17ms/step - accuracy: 0.9423 - loss: 0.1610 - val_accuracy: 0.9344 - val_loss: 0.1679 - learning_rate: 1.0000e-04
# Epoch 20/150
#   [Epoch 020]  time=2.3s | CPU=0% | RAM=4.83GB (4%) | GPU=0% | GPU_Mem=4556MB
# 164/164 - 3s - 17ms/step - accuracy: 0.9333 - loss: 0.1789 - val_accuracy: 0.9353 - val_loss: 0.1668 - learning_rate: 1.0000e-04
# Epoch 21/150
#   [Epoch 021]  time=2.3s | CPU=9% | RAM=4.81GB (4%) | GPU=0% | GPU_Mem=4556MB
# 164/164 - 3s - 17ms/step - accuracy: 0.9465 - loss: 0.1502 - val_accuracy: 0.9420 - val_loss: 0.1550 - learning_rate: 1.0000e-04
# Epoch 22/150
#   [Epoch 022]  time=2.3s | CPU=1% | RAM=4.78GB (4%) | GPU=0% | GPU_Mem=4556MB
# 164/164 - 3s - 17ms/step - accuracy: 0.9516 - loss: 0.1374 - val_accuracy: 0.9417 - val_loss: 0.1538 - learning_rate: 1.0000e-04
# Epoch 23/150
#   [Epoch 023]  time=2.3s | CPU=0% | RAM=4.80GB (4%) | GPU=0% | GPU_Mem=4556MB
# 164/164 - 3s - 17ms/step - accuracy: 0.9428 - loss: 0.1564 - val_accuracy: 0.9213 - val_loss: 0.2035 - learning_rate: 1.0000e-04
# Epoch 24/150
#   [Epoch 024]  time=2.3s | CPU=0% | RAM=4.80GB (4%) | GPU=0% | GPU_Mem=4556MB
# 164/164 - 3s - 17ms/step - accuracy: 0.9480 - loss: 0.1448 - val_accuracy: 0.9403 - val_loss: 0.1560 - learning_rate: 1.0000e-04
# Epoch 25/150
#   [Epoch 025]  time=2.3s | CPU=1% | RAM=4.81GB (4%) | GPU=0% | GPU_Mem=4556MB
# 164/164 - 3s - 17ms/step - accuracy: 0.9523 - loss: 0.1345 - val_accuracy: 0.9393 - val_loss: 0.1566 - learning_rate: 1.0000e-04
# Epoch 26/150
#   [Epoch 026]  time=2.3s | CPU=9% | RAM=4.81GB (4%) | GPU=0% | GPU_Mem=4556MB
# 164/164 - 3s - 17ms/step - accuracy: 0.9507 - loss: 0.1359 - val_accuracy: 0.9408 - val_loss: 0.1542 - learning_rate: 1.0000e-04
# Epoch 27/150
#   [Epoch 027]  time=2.3s | CPU=0% | RAM=4.81GB (4%) | GPU=0% | GPU_Mem=4556MB
# 164/164 - 3s - 17ms/step - accuracy: 0.9569 - loss: 0.1208 - val_accuracy: 0.9437 - val_loss: 0.1458 - learning_rate: 1.0000e-04
# Epoch 28/150
#   [Epoch 028]  time=2.3s | CPU=0% | RAM=4.82GB (4%) | GPU=0% | GPU_Mem=4556MB
# 164/164 - 3s - 17ms/step - accuracy: 0.9593 - loss: 0.1134 - val_accuracy: 0.9448 - val_loss: 0.1448 - learning_rate: 1.0000e-04
# Epoch 29/150
#   [Epoch 029]  time=2.3s | CPU=0% | RAM=4.80GB (4%) | GPU=0% | GPU_Mem=4556MB
# 164/164 - 3s - 17ms/step - accuracy: 0.9605 - loss: 0.1113 - val_accuracy: 0.9456 - val_loss: 0.1463 - learning_rate: 1.0000e-04
# Epoch 30/150
#   [Epoch 030]  time=2.3s | CPU=9% | RAM=4.84GB (4%) | GPU=0% | GPU_Mem=4556MB
# 164/164 - 3s - 17ms/step - accuracy: 0.9601 - loss: 0.1113 - val_accuracy: 0.9379 - val_loss: 0.1799 - learning_rate: 1.0000e-04
# Epoch 31/150
#   [Epoch 031]  time=2.3s | CPU=0% | RAM=4.84GB (4%) | GPU=0% | GPU_Mem=4556MB
# 164/164 - 3s - 17ms/step - accuracy: 0.9269 - loss: 0.1942 - val_accuracy: 0.9292 - val_loss: 0.1967 - learning_rate: 1.0000e-04
# Epoch 32/150
#   [Epoch 032]  time=2.2s | CPU=1% | RAM=4.84GB (4%) | GPU=0% | GPU_Mem=4556MB
# 164/164 - 3s - 17ms/step - accuracy: 0.9388 - loss: 0.1602 - val_accuracy: 0.9390 - val_loss: 0.1600 - learning_rate: 1.0000e-04
# Epoch 33/150
#   [Epoch 033]  time=2.2s | CPU=0% | RAM=4.84GB (4%) | GPU=0% | GPU_Mem=4556MB
# 164/164 - 3s - 17ms/step - accuracy: 0.9561 - loss: 0.1206 - val_accuracy: 0.9439 - val_loss: 0.1468 - learning_rate: 1.0000e-04
# Epoch 34/150
#   [Epoch 034]  time=2.2s | CPU=0% | RAM=4.82GB (4%) | GPU=0% | GPU_Mem=4556MB
# 164/164 - 3s - 17ms/step - accuracy: 0.9482 - loss: 0.1399 - val_accuracy: 0.9434 - val_loss: 0.1468 - learning_rate: 1.0000e-04
# Epoch 35/150
#   [Epoch 035]  time=2.3s | CPU=6% | RAM=4.79GB (4%) | GPU=0% | GPU_Mem=4556MB
# 164/164 - 3s - 17ms/step - accuracy: 0.9625 - loss: 0.1050 - val_accuracy: 0.9457 - val_loss: 0.1399 - learning_rate: 5.0000e-05
# Epoch 36/150
#   [Epoch 036]  time=2.3s | CPU=1% | RAM=4.80GB (4%) | GPU=0% | GPU_Mem=4556MB
# 164/164 - 3s - 17ms/step - accuracy: 0.9605 - loss: 0.1094 - val_accuracy: 0.9478 - val_loss: 0.1349 - learning_rate: 5.0000e-05
# Epoch 37/150
#   [Epoch 037]  time=2.3s | CPU=0% | RAM=4.81GB (4%) | GPU=0% | GPU_Mem=4556MB
# 164/164 - 3s - 17ms/step - accuracy: 0.9644 - loss: 0.1000 - val_accuracy: 0.9495 - val_loss: 0.1325 - learning_rate: 5.0000e-05
# Epoch 38/150
#   [Epoch 038]  time=2.2s | CPU=0% | RAM=4.81GB (4%) | GPU=0% | GPU_Mem=4556MB
# 164/164 - 3s - 17ms/step - accuracy: 0.9649 - loss: 0.0982 - val_accuracy: 0.9502 - val_loss: 0.1330 - learning_rate: 5.0000e-05
# Epoch 39/150
#   [Epoch 039]  time=2.3s | CPU=10% | RAM=4.79GB (4%) | GPU=0% | GPU_Mem=4556MB
# 164/164 - 3s - 17ms/step - accuracy: 0.9640 - loss: 0.0994 - val_accuracy: 0.9500 - val_loss: 0.1333 - learning_rate: 5.0000e-05
# Epoch 40/150
#   [Epoch 040]  time=2.3s | CPU=0% | RAM=4.79GB (4%) | GPU=0% | GPU_Mem=4556MB
# 164/164 - 3s - 17ms/step - accuracy: 0.9666 - loss: 0.0931 - val_accuracy: 0.9469 - val_loss: 0.1430 - learning_rate: 5.0000e-05
# Epoch 41/150
#   [Epoch 041]  time=2.3s | CPU=0% | RAM=4.81GB (4%) | GPU=0% | GPU_Mem=4556MB
# 164/164 - 3s - 17ms/step - accuracy: 0.9645 - loss: 0.0981 - val_accuracy: 0.9509 - val_loss: 0.1318 - learning_rate: 5.0000e-05
# Epoch 42/150
#   [Epoch 042]  time=2.2s | CPU=0% | RAM=4.81GB (4%) | GPU=0% | GPU_Mem=4556MB
# 164/164 - 3s - 17ms/step - accuracy: 0.9660 - loss: 0.0946 - val_accuracy: 0.9501 - val_loss: 0.1346 - learning_rate: 5.0000e-05
# Epoch 43/150
#   [Epoch 043]  time=2.3s | CPU=3% | RAM=4.80GB (4%) | GPU=0% | GPU_Mem=4556MB
# 164/164 - 3s - 17ms/step - accuracy: 0.9682 - loss: 0.0884 - val_accuracy: 0.9518 - val_loss: 0.1315 - learning_rate: 5.0000e-05
# Epoch 44/150
#   [Epoch 044]  time=2.3s | CPU=1% | RAM=4.83GB (4%) | GPU=0% | GPU_Mem=4556MB
# 164/164 - 3s - 17ms/step - accuracy: 0.9692 - loss: 0.0849 - val_accuracy: 0.9523 - val_loss: 0.1274 - learning_rate: 5.0000e-05
# Epoch 45/150
#   [Epoch 045]  time=2.3s | CPU=0% | RAM=4.81GB (4%) | GPU=0% | GPU_Mem=4556MB
# 164/164 - 3s - 17ms/step - accuracy: 0.9664 - loss: 0.0929 - val_accuracy: 0.9517 - val_loss: 0.1296 - learning_rate: 5.0000e-05
# Epoch 46/150
#   [Epoch 046]  time=2.2s | CPU=0% | RAM=4.83GB (4%) | GPU=0% | GPU_Mem=4556MB
# 164/164 - 3s - 17ms/step - accuracy: 0.9696 - loss: 0.0844 - val_accuracy: 0.9525 - val_loss: 0.1282 - learning_rate: 5.0000e-05
# Epoch 47/150
#   [Epoch 047]  time=2.2s | CPU=0% | RAM=4.83GB (4%) | GPU=0% | GPU_Mem=4556MB
# 164/164 - 3s - 17ms/step - accuracy: 0.9658 - loss: 0.0939 - val_accuracy: 0.9512 - val_loss: 0.1321 - learning_rate: 5.0000e-05
# Epoch 48/150
#   [Epoch 048]  time=2.2s | CPU=9% | RAM=4.85GB (4%) | GPU=0% | GPU_Mem=4556MB
# 164/164 - 3s - 17ms/step - accuracy: 0.9680 - loss: 0.0887 - val_accuracy: 0.9508 - val_loss: 0.1372 - learning_rate: 5.0000e-05
# Epoch 49/150
#   [Epoch 049]  time=2.3s | CPU=0% | RAM=4.81GB (4%) | GPU=0% | GPU_Mem=4556MB
# 164/164 - 3s - 17ms/step - accuracy: 0.9635 - loss: 0.1000 - val_accuracy: 0.9503 - val_loss: 0.1317 - learning_rate: 5.0000e-05
# Epoch 50/150
#   [Epoch 050]  time=2.3s | CPU=1% | RAM=4.83GB (4%) | GPU=0% | GPU_Mem=4556MB
# 164/164 - 3s - 17ms/step - accuracy: 0.9699 - loss: 0.0834 - val_accuracy: 0.9522 - val_loss: 0.1299 - learning_rate: 5.0000e-05
# Epoch 51/150
#   [Epoch 051]  time=2.3s | CPU=0% | RAM=4.85GB (4%) | GPU=0% | GPU_Mem=4556MB
# 164/164 - 3s - 17ms/step - accuracy: 0.9675 - loss: 0.0889 - val_accuracy: 0.9521 - val_loss: 0.1274 - learning_rate: 5.0000e-05
# Epoch 52/150
#   [Epoch 052]  time=2.3s | CPU=4% | RAM=4.80GB (4%) | GPU=0% | GPU_Mem=4556MB
# 164/164 - 3s - 17ms/step - accuracy: 0.9712 - loss: 0.0796 - val_accuracy: 0.9529 - val_loss: 0.1260 - learning_rate: 5.0000e-05
# Epoch 53/150
#   [Epoch 053]  time=2.3s | CPU=1% | RAM=4.83GB (4%) | GPU=0% | GPU_Mem=4556MB
# 164/164 - 3s - 17ms/step - accuracy: 0.9705 - loss: 0.0813 - val_accuracy: 0.9539 - val_loss: 0.1249 - learning_rate: 5.0000e-05
# Epoch 54/150
#   [Epoch 054]  time=2.3s | CPU=0% | RAM=4.82GB (4%) | GPU=0% | GPU_Mem=4556MB
# 164/164 - 3s - 17ms/step - accuracy: 0.9721 - loss: 0.0771 - val_accuracy: 0.9524 - val_loss: 0.1312 - learning_rate: 5.0000e-05
# Epoch 55/150
#   [Epoch 055]  time=2.3s | CPU=0% | RAM=4.83GB (4%) | GPU=0% | GPU_Mem=4556MB
# 164/164 - 3s - 17ms/step - accuracy: 0.9665 - loss: 0.0911 - val_accuracy: 0.9530 - val_loss: 0.1275 - learning_rate: 5.0000e-05
# Epoch 56/150
#   [Epoch 056]  time=2.2s | CPU=1% | RAM=4.84GB (4%) | GPU=0% | GPU_Mem=4556MB
# 164/164 - 3s - 17ms/step - accuracy: 0.9715 - loss: 0.0790 - val_accuracy: 0.9530 - val_loss: 0.1288 - learning_rate: 5.0000e-05
# Epoch 57/150
#   [Epoch 057]  time=2.3s | CPU=9% | RAM=4.85GB (4%) | GPU=0% | GPU_Mem=4556MB
# 164/164 - 3s - 17ms/step - accuracy: 0.9685 - loss: 0.0863 - val_accuracy: 0.9528 - val_loss: 0.1260 - learning_rate: 5.0000e-05
# Epoch 58/150
#   [Epoch 058]  time=2.2s | CPU=0% | RAM=4.81GB (4%) | GPU=0% | GPU_Mem=4556MB
# 164/164 - 3s - 17ms/step - accuracy: 0.9719 - loss: 0.0774 - val_accuracy: 0.9534 - val_loss: 0.1299 - learning_rate: 5.0000e-05
# Epoch 59/150
#   [Epoch 059]  time=2.2s | CPU=0% | RAM=4.80GB (4%) | GPU=0% | GPU_Mem=4556MB
# 164/164 - 3s - 17ms/step - accuracy: 0.9712 - loss: 0.0787 - val_accuracy: 0.9545 - val_loss: 0.1257 - learning_rate: 5.0000e-05
# Epoch 60/150
#   [Epoch 060]  time=2.2s | CPU=1% | RAM=4.82GB (4%) | GPU=0% | GPU_Mem=4556MB
# 164/164 - 3s - 17ms/step - accuracy: 0.9732 - loss: 0.0739 - val_accuracy: 0.9544 - val_loss: 0.1252 - learning_rate: 2.5000e-05
# Epoch 61/150
#   [Epoch 061]  time=2.2s | CPU=4% | RAM=4.84GB (4%) | GPU=0% | GPU_Mem=4556MB
# 164/164 - 3s - 17ms/step - accuracy: 0.9729 - loss: 0.0750 - val_accuracy: 0.9543 - val_loss: 0.1253 - learning_rate: 2.5000e-05
# Epoch 62/150
#   [Epoch 062]  time=2.3s | CPU=0% | RAM=4.82GB (4%) | GPU=0% | GPU_Mem=4556MB
# 164/164 - 3s - 17ms/step - accuracy: 0.9736 - loss: 0.0725 - val_accuracy: 0.9547 - val_loss: 0.1268 - learning_rate: 2.5000e-05
# Epoch 63/150
#   [Epoch 063]  time=2.3s | CPU=2% | RAM=4.84GB (4%) | GPU=0% | GPU_Mem=4556MB
# 164/164 - 3s - 17ms/step - accuracy: 0.9732 - loss: 0.0740 - val_accuracy: 0.9545 - val_loss: 0.1273 - learning_rate: 2.5000e-05
# Epoch 64/150
#   [Epoch 064]  time=2.3s | CPU=0% | RAM=4.85GB (4%) | GPU=0% | GPU_Mem=4556MB
# 164/164 - 3s - 17ms/step - accuracy: 0.9739 - loss: 0.0717 - val_accuracy: 0.9528 - val_loss: 0.1293 - learning_rate: 2.5000e-05
# Epoch 65/150
#   [Epoch 065]  time=2.2s | CPU=0% | RAM=4.85GB (4%) | GPU=0% | GPU_Mem=4556MB
# 164/164 - 3s - 17ms/step - accuracy: 0.9732 - loss: 0.0729 - val_accuracy: 0.9544 - val_loss: 0.1270 - learning_rate: 2.5000e-05
# Epoch 66/150
#   [Epoch 066]  time=2.3s | CPU=8% | RAM=4.81GB (4%) | GPU=0% | GPU_Mem=4556MB
# 164/164 - 3s - 17ms/step - accuracy: 0.9746 - loss: 0.0699 - val_accuracy: 0.9554 - val_loss: 0.1261 - learning_rate: 2.5000e-05
# Epoch 67/150
#   [Epoch 067]  time=2.3s | CPU=0% | RAM=4.81GB (4%) | GPU=0% | GPU_Mem=4556MB
# 164/164 - 3s - 17ms/step - accuracy: 0.9748 - loss: 0.0689 - val_accuracy: 0.9551 - val_loss: 0.1251 - learning_rate: 2.5000e-05
# Epoch 68/150
#   [Epoch 068]  time=2.3s | CPU=0% | RAM=4.81GB (4%) | GPU=0% | GPU_Mem=4556MB
# 164/164 - 3s - 17ms/step - accuracy: 0.9753 - loss: 0.0675 - val_accuracy: 0.9554 - val_loss: 0.1254 - learning_rate: 2.5000e-05
#
# ============================================================
#   Training Complete — Total wall time: 254.9s
# ============================================================
#
# ==================================================
#   Resource Snapshot: After Training
# ==================================================
#   CPU Usage       : 0.7%
#   RAM Used        : 4.81 GB / 179.37 GB  (3.5%)
#   GPU Utilization : 0.0%
#   GPU Memory      : 4556 MB / 81920 MB  (5.6%)
# ==================================================

# %%
resource_monitor.get_usage()
# Out:
# ══════════════════════════════════════════════════════════════
#   POST-TRAINING RESOURCE USAGE  (68 epochs)
# ══════════════════════════════════════════════════════════════
#   Metric                     Avg       Max       Min
#   --------------------  --------  --------  --------
#   Epoch Time (s)             3.2      65.8       2.2
#   CPU (%)                    2.0      10.5       0.0
#   RAM (GB)                  4.81      4.85      4.75
#   RAM (%)                    3.5       3.6       3.5
#   Train Loss              0.1488    0.5228    0.0675
#   Val Loss                0.3773    7.4795    0.1249
#   GPU Util (%)               0.0       0.0       0.0
#   GPU Memory (MB)         4556.0    4556.0    4554.0
# ══════════════════════════════════════════════════════════════

# %%
def plot_history(history):
    plt.figure(figsize=(12, 4))

    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'], label='Training Accuracy')
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
    plt.title('Training vs Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.ylim(0.5, 1)
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title('Training vs Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.ylim(0, 1)
    plt.legend()

    plt.show()

plot_history(history)

# %%
# Generate predictions
test_start_time = time.time()
y_pred = model.predict(X_test)
test_end_time = time.time()

y_pred_labels = (y_pred >= 0.5).astype(int)
print(y_pred_labels.shape)
unique_values, counts = np.unique(y_pred_labels, return_counts=True)
print("Unique values:", unique_values)
print("Counts:", counts)
# Out:
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 13s 484ms/step
# (436, 128, 128, 1)
# Unique values: [0 1]
# Counts: [3999611 3143813]

# %%
# Calculate training & testing time
training_time = train_end_time - train_start_time
testing_time = test_end_time - test_start_time

print(f"Training time: {training_time:.2f} seconds")
print(f"Testing time: {testing_time:.2f} seconds")

# Calculate total time
total_time = training_time + testing_time
print(f"Total time: {total_time:.2f} seconds")
# Out:
# Training time: 255.87 seconds
# Testing time: 13.59 seconds
# Total time: 269.47 seconds

# %%
# Visualize some example predictions
def plot_sample_predictions(X, y_true, y_pred, sample_count=2):
    for i in range(sample_count):
        plt.figure(figsize=(12, 6))

        plt.subplot(1, 3, 1)
        plt.title('Input Image')
        plt.imshow(X[i,:,:,-1].squeeze())

        plt.subplot(1, 3, 2)
        plt.title('True Mask')
        plt.imshow(y_true[i].squeeze(), cmap='gray')

        plt.subplot(1, 3, 3)
        plt.title('Predicted Mask')
        plt.imshow(y_pred[i].squeeze(), cmap='gray')

        plt.show()

# Plot some sample predictions
plot_sample_predictions(X_test, y_test, y_pred_labels)

# %%
# Extract the final accuracy and loss values
final_train_accuracy = history.history['accuracy'][-1]
final_val_accuracy = history.history['val_accuracy'][-1]
final_train_loss = history.history['loss'][-1]
final_val_loss = history.history['val_loss'][-1]

# Print the final results
print(f"Final Training Accuracy: {final_train_accuracy:.4f}")
print(f"Final Validation Accuracy: {final_val_accuracy:.4f}")
print(f"Final Training Loss: {final_train_loss:.4f}")
print(f"Final Validation Loss: {final_val_loss:.4f}")
# Out:
# Final Training Accuracy: 0.9753
# Final Validation Accuracy: 0.9554
# Final Training Loss: 0.0675
# Final Validation Loss: 0.1254

# %% [markdown]
# # Evaluation

# %%
def precision_score_(groundtruth_mask, pred_mask):
    intersect = np.sum(pred_mask*groundtruth_mask)
    total_pixel_pred = np.sum(pred_mask)
    precision = np.mean(intersect/total_pixel_pred)
    return round(precision, 3)

def recall_score_(groundtruth_mask, pred_mask):
    intersect = np.sum(pred_mask*groundtruth_mask)
    total_pixel_truth = np.sum(groundtruth_mask)
    recall = np.mean(intersect/total_pixel_truth)
    return round(recall, 3)

def accuracy(groundtruth_mask, pred_mask):
    intersect = np.sum(pred_mask*groundtruth_mask)
    union = np.sum(pred_mask) + np.sum(groundtruth_mask) - intersect
    xor = np.sum(groundtruth_mask==pred_mask)
    acc = np.mean(xor/(union + xor - intersect))
    return round(acc, 3)

def dice_coef(groundtruth_mask, pred_mask):
    intersect = np.sum(pred_mask*groundtruth_mask)
    total_sum = np.sum(pred_mask) + np.sum(groundtruth_mask)
    dice = np.mean(2*intersect/total_sum)
    return round(dice, 3) #round up to 3 decimal places

def iou(groundtruth_mask, pred_mask):
    intersect = np.sum(pred_mask*groundtruth_mask)
    union = np.sum(pred_mask) + np.sum(groundtruth_mask) - intersect
    iou = np.mean(intersect/union)
    return round(iou, 3)

def metrics_table(mask, pred):
    metrics = {'Precision':[],'Recall':[],'Accuracy':[],'Dice':[],'IoU':[]}
    metrics['Precision'].append(precision_score_(mask, pred))
    metrics['Recall'].append(recall_score_(mask, pred))
    metrics['Accuracy'].append(accuracy(mask, pred))
    metrics['Dice'].append(dice_coef(mask, pred))
    metrics['IoU'].append(iou(mask, pred))
    df = pd.DataFrame.from_dict(metrics)
    df.columns = ['Precision', 'Recall', 'Accuracy', 'Dice', 'IoU']
    return df

metrics_table(y_test, y_pred_labels)
# Out:
#    Precision  Recall  Accuracy   Dice    IoU
# 0      0.939   0.963     0.957  0.951  0.906

# %%
y_test_flat = y_test.flatten()
y_labels_flat = y_pred_labels.flatten()

overall_accuracy = accuracy_score(y_test_flat, y_labels_flat)

print(f"Overall accuracy: {overall_accuracy:.4f}")
# Out:
# Overall accuracy: 0.9573

# %%
FP = len(np.where(y_pred_labels - y_test  == 1)[0])
FN = len(np.where(y_pred_labels - y_test  == -1)[0])
TP = len(np.where(y_pred_labels + y_test == 2)[0])
TN = len(np.where(y_pred_labels + y_test == 0)[0])
cmat = [[TP, FN], [FP, TN]]

plt.figure(figsize = (8, 6))
sns.heatmap(cmat/np.sum(cmat), cmap="Blues", annot=True, fmt = '.2%')
plt.title('Confusion Matrix S2 Bands')
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
plt.show()

# %% [markdown]
# # Prediction

# %%
def reconstruct_image(splitted_array):
    # Initialize the reconstructed image array
    reconstructed_image = np.zeros((256, 256, 1), dtype=splitted_array.dtype)

    # Define the size of the small images
    small_image_size = 128

    # Loop over the 4 small images
    for i in range(4):
        # Calculate the position of the small image in the original image
        row = (i // 2) * small_image_size
        col = (i % 2) * small_image_size

        # Place the small image in the correct position
        reconstructed_image[row:row + small_image_size, col:col + small_image_size, :] = splitted_array[i]

    return reconstructed_image

def normalize(band):
    band_min, band_max = (band.min(), band.max())
    return ((band-band_min)/((band_max - band_min)))

def gammacorr(band):
    gamma=25
    return np.power(band, 1/gamma)

# %%
# Load Sentinel image data
with rio.open(data_dir + '5_20240818T024529_20240818T030428_T48MZT.tif') as src:
    s_data = src.read()
    s_data = np.moveaxis(s_data, 0, -1)
    profile = src.profile

# Load ground truth data
with rio.open(mask_dir + 'Mask_1.tif') as src:
    ground_truth = src.read()
    ground_truth = np.moveaxis(ground_truth, 0, -1)

splitter = SlidingWindowSplitter(window, window)
bands_patches, mask_patches, patch_ids = splitter(s_data, ground_truth)

bpatches = np.array(bands_patches)
mpatches = np.array(mask_patches)
ipatches = np.array(patch_ids)

# Generate predictions
prediction = model.predict(bpatches)
prediction_labels = (prediction >= 0.5).astype(int)

reconstructed_image = reconstruct_image(prediction_labels)
ground_truth_cropped = ground_truth[0:256, 0:256, :]
s_data_cropped = s_data[0:256, 0:256, 0:3]

red_b=gammacorr(s_data_cropped[:,:,2])
green_b=gammacorr(s_data_cropped[:,:,1])
blue_b=gammacorr(s_data_cropped[:,:,0])
red_bn=normalize(red_b)
green_bn=normalize(green_b)
blue_bn=normalize(blue_b)
rgb_composite_n= np.dstack((red_bn, green_bn, blue_bn))

# Define the colormap
cmap = ListedColormap(['white', 'green'])

# Show prediction
plt.figure(figsize=(12, 6))
plt.subplot(1,2,1)
plt.imshow(rgb_composite_n.squeeze())
plt.title('Original Sentinel Data')
plt.subplot(1,2,2)
plt.imshow(reconstructed_image.squeeze(), cmap=cmap, norm=plt.Normalize(vmin=0, vmax=1))
plt.title('Predicted')
# Out:
# ---------------------------------------------------------------------------
# CPLE_OpenFailedError                      Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/rasterio/_base.pyx in rasterio._base.DatasetBase.__init__()
#
# /usr/local/lib/python3.12/dist-packages/rasterio/_base.pyx in rasterio._base.open_dataset()
#
# /usr/local/lib/python3.12/dist-packages/rasterio/_err.pyx in rasterio._err.exc_wrap_pointer()
#
# CPLE_OpenFailedError: /content/drive/MyDrive/S2_NDWI_Filtered/5_20240818T024529_20240818T030428_T48MZT.tif: No such file or directory
#
# During handling of the above exception, another exception occurred:
#
# RasterioIOError                           Traceback (most recent call last)
# /tmp/ipykernel_5480/2976061330.py in <cell line: 0>()
#       1 # Load Sentinel image data
# ----> 2 with rio.open(data_dir + '5_20240818T024529_20240818T030428_T48MZT.tif') as src:
#       3     s_data = src.read()
#       4     s_data = np.moveaxis(s_data, 0, -1)
#       5     profile = src.profile
#
# /usr/local/lib/python3.12/dist-packages/rasterio/env.py in wrapper(*args, **kwds)
#     462
#     463         with env_ctor(session=session):
# --> 464             return f(*args, **kwds)
#     465
#     466     return wrapper
#
# /usr/local/lib/python3.12/dist-packages/rasterio/__init__.py in open(fp, mode, driver, width, height, count, crs, transform, dtype, nodata, sharing, thread_safe, opener, **kwargs)
#     365
#     366             if mode == "r":
# --> 367                 dataset = DatasetReader(path, driver=driver, sharing=sharing, thread_safe=thread_safe, **kwargs)
#     368             elif mode == "r+":
#     369                 dataset = get_writer_for_path(path, driver=driver)(
#
# /usr/local/lib/python3.12/dist-packages/rasterio/_base.pyx in rasterio._base.DatasetBase.__init__()
#
# RasterioIOError: /content/drive/MyDrive/S2_NDWI_Filtered/5_20240818T024529_20240818T030428_T48MZT.tif: No such file or directory

# %%
# Load Sentinel image data
with rio.open(data_dir + '6_20240530T024529_20240530T030903_T48MZU.tif') as src:
    s_data = src.read()
    s_data = np.moveaxis(s_data, 0, -1)
    profile = src.profile

# Load ground truth data
with rio.open(mask_dir + 'Mask_1.tif') as src:
    ground_truth = src.read()
    ground_truth = np.moveaxis(ground_truth, 0, -1)

splitter = SlidingWindowSplitter(window, window)
bands_patches, mask_patches, patch_ids = splitter(s_data, ground_truth)

bpatches = np.array(bands_patches)
mpatches = np.array(mask_patches)
ipatches = np.array(patch_ids)

# Generate predictions
prediction = model.predict(bpatches)
prediction_labels = (prediction >= 0.5).astype(int)

reconstructed_image = reconstruct_image(prediction_labels)
ground_truth_cropped = ground_truth[0:256, 0:256, :]
s_data_cropped = s_data[0:256, 0:256, 0:3]

red_b=gammacorr(s_data_cropped[:,:,2])
green_b=gammacorr(s_data_cropped[:,:,1])
blue_b=gammacorr(s_data_cropped[:,:,0])
red_bn=normalize(red_b)
green_bn=normalize(green_b)
blue_bn=normalize(blue_b)
rgb_composite_n= np.dstack((red_bn, green_bn, blue_bn))

# Define the colormap
cmap = ListedColormap(['white', 'green'])

# Show prediction
plt.figure(figsize=(12, 6))
plt.subplot(1,2,1)
plt.imshow(rgb_composite_n.squeeze())
plt.title('Original Sentinel Data')
plt.subplot(1,2,2)
plt.imshow(reconstructed_image.squeeze(), cmap=cmap, norm=plt.Normalize(vmin=0, vmax=1))
plt.title('Predicted')

# %%
# Load Sentinel image data
with rio.open(data_dir + '7_20240813T024531_20240813T030507_T48MZU.tif') as src:
    s_data = src.read()
    s_data = np.moveaxis(s_data, 0, -1)
    profile = src.profile

# Load ground truth data
with rio.open(mask_dir + 'Mask_1.tif') as src:
    ground_truth = src.read()
    ground_truth = np.moveaxis(ground_truth, 0, -1)

splitter = SlidingWindowSplitter(window, window)
bands_patches, mask_patches, patch_ids = splitter(s_data, ground_truth)

bpatches = np.array(bands_patches)
mpatches = np.array(mask_patches)
ipatches = np.array(patch_ids)

# Generate predictions
prediction = model.predict(bpatches)
prediction_labels = (prediction >= 0.5).astype(int)

reconstructed_image = reconstruct_image(prediction_labels)
ground_truth_cropped = ground_truth[0:256, 0:256, :]
s_data_cropped = s_data[0:256, 0:256, 0:3]

red_b=gammacorr(s_data_cropped[:,:,2])
green_b=gammacorr(s_data_cropped[:,:,1])
blue_b=gammacorr(s_data_cropped[:,:,0])
red_bn=normalize(red_b)
green_bn=normalize(green_b)
blue_bn=normalize(blue_b)
rgb_composite_n= np.dstack((red_bn, green_bn, blue_bn))

# Define the colormap
cmap = ListedColormap(['white', 'green'])

# Show prediction
plt.figure(figsize=(12, 6))
plt.subplot(1,2,1)
plt.imshow(rgb_composite_n.squeeze())
plt.title('Original Sentinel Data')
plt.subplot(1,2,2)
plt.imshow(reconstructed_image.squeeze(), cmap=cmap, norm=plt.Normalize(vmin=0, vmax=1))
plt.title('Predicted')

# %%
# Load Sentinel image data
with rio.open(data_dir + '8_20240712T025529_20240712T031251_T48MZT.tif') as src:
    s_data = src.read()
    s_data = np.moveaxis(s_data, 0, -1)
    profile = src.profile

# Load ground truth data
with rio.open(mask_dir + 'Mask_1.tif') as src:
    ground_truth = src.read()
    ground_truth = np.moveaxis(ground_truth, 0, -1)

splitter = SlidingWindowSplitter(window, window)
bands_patches, mask_patches, patch_ids = splitter(s_data, ground_truth)

bpatches = np.array(bands_patches)
mpatches = np.array(mask_patches)
ipatches = np.array(patch_ids)

# Generate predictions
prediction = model.predict(bpatches)
prediction_labels = (prediction >= 0.5).astype(int)

reconstructed_image = reconstruct_image(prediction_labels)
ground_truth_cropped = ground_truth[0:256, 0:256, :]
s_data_cropped = s_data[0:256, 0:256, 0:3]

red_b=gammacorr(s_data_cropped[:,:,2])
green_b=gammacorr(s_data_cropped[:,:,1])
blue_b=gammacorr(s_data_cropped[:,:,0])
red_bn=normalize(red_b)
green_bn=normalize(green_b)
blue_bn=normalize(blue_b)
rgb_composite_n= np.dstack((red_bn, green_bn, blue_bn))

# Define the colormap
cmap = ListedColormap(['white', 'green'])

# Show prediction
plt.figure(figsize=(12, 6))
plt.subplot(1,2,1)
plt.imshow(rgb_composite_n.squeeze())
plt.title('Original Sentinel Data')
plt.subplot(1,2,2)
plt.imshow(reconstructed_image.squeeze(), cmap=cmap, norm=plt.Normalize(vmin=0, vmax=1))
plt.title('Predicted')

# %% [markdown]
# # Save Models

# %%
model_dir = '/content/drive/MyDrive/Skripsi_Padi/TransUNet_3.keras'
model.save(model_dir)
